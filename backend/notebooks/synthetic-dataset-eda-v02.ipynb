# %%
import pandas as pd

# Load the dataset
file_path = '../data/synthetic_australian_real_estate.csv'
df = pd.read_csv(file_path)

# Display basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   rea_property_id             10000 non-null  int64
#  1   property_type               10000 non-null  object
#  2   state                       10000 non-null  object
#  3   postcode                    10000 non-null  int64
#  4   year_built                  10000 non-null  int64
#  5   last_sold_date              10000 non-null  object
#  6   last_sold_agency            10000 non-null  object
#  7   bedrooms                    10000 non-null  int64
#  8   bathrooms                   10000 non-null  int64
#  9   findagentsuri               10000 non-null  object
#  10  floor_area                  10000 non-null  object
#  11  fullsuburb                  10000 non-null  object
#  12  house_type                  10000 non-null  object
# ...

# %%
# Show the first five rows to understand the dataset structure
df.head()
# Out:
#    rea_property_id property_type state  postcode  year_built last_sold_date  \
# 0          4322577     Townhouse    NT      4159        1937     2011-02-01
# 1          1795147     Townhouse    NT      5034        1953     2020-02-04
# 2          2648223     Apartment   NSW      2992        1988     2003-10-02
# 3          2705182     Apartment   Qld      6897        2002     2018-08-17
# 4          5402063          Unit   Qld      2764        1980     2005-12-25
#
#              last_sold_agency  bedrooms  bathrooms             findagentsuri  \
# 0                 Green Group         2          3  https://baker-brown.net/
# 1                    Cruz LLC         2          1        http://walker.biz/
# 2                 Escobar Ltd         4          2       http://ramirez.edu/
# 3           Bautista and Sons         4          3  https://www.sawyer.info/
# 4  Daniel, Jacobs and Jimenez         3          2   http://www.kerr.edu.au/
#
# ...

# %%
# Check for missing values in the dataset
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
# Display summary statistics for numerical columns
df.describe()
# Out:
#        rea_property_id      postcode    year_built     bedrooms     bathrooms  \
# count     1.000000e+04  10000.000000  10000.000000  10000.00000  10000.000000
# mean      5.515977e+06   5013.526200   1959.967300      3.00030      1.992900
# std       2.600182e+06   1720.738594     35.031976      1.41651      0.817262
# min       1.001345e+06   2000.000000   1900.000000      1.00000      1.000000
# 25%       3.233270e+06   3532.000000   1930.000000      2.00000      1.000000
# 50%       5.504288e+06   5043.000000   1960.000000      3.00000      2.000000
# 75%       7.803551e+06   6501.250000   1990.000000      4.00000      3.000000
# max       9.998016e+06   7999.000000   2021.000000      5.00000      3.000000
#
#                 lat           lon  photo_count  land_size_num  floor_area_num  \
# count  10000.000000  10000.000000  10000.00000   10000.000000    10000.000000
# mean     -23.938204    133.487618     10.45670     751.991400      250.352752
# ...

# %%
# Analyze the distribution of property types
if 'property_type' in df.columns:
    print("Property Type Distribution:")
    print(df['property_type'].value_counts())
# Out:
# Property Type Distribution:
# property_type
# Apartment    2523
# Unit         2507
# Townhouse    2493
# House        2477
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Analyze the distribution of bedrooms and bathrooms
if 'bedrooms' in df.columns and 'bathrooms' in df.columns:
    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    sns.countplot(data=df, x='bedrooms')
    plt.title("Distribution of Bedrooms")
    
    plt.subplot(1, 2, 2)
    sns.countplot(data=df, x='bathrooms')
    plt.title("Distribution of Bathrooms")
    
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

# Analyze the distribution of estimated property prices
if 'estimated_price' in df.columns:
    plt.figure(figsize=(10, 5))
    sns.histplot(df['estimated_price'], bins=30, kde=True)
    plt.title("Estimated Price Distribution")
    plt.xlabel("Estimated Price")
    plt.ylabel("Frequency")
    plt.show()

# %%
# Analyze the distribution of land size and floor area
if 'land_size_num' in df.columns and 'floor_area_num' in df.columns:
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    sns.histplot(df['land_size_num'], bins=30, kde=True)
    plt.title("Land Size Distribution")
    plt.xlabel("Land Size")
    
    plt.subplot(1, 2, 2)
    sns.histplot(df['floor_area_num'], bins=30, kde=True)
    plt.title("Floor Area Distribution")
    plt.xlabel("Floor Area")
    
    plt.tight_layout()
    plt.show()

# %%
# Analyze the distribution of properties by suburb and state
if 'suburb' in df.columns:
    print("Top 10 Suburbs by Property Count:")
    print(df['suburb'].value_counts().head(10))

if 'state' in df.columns:
    print("\nProperties by State:")
    print(df['state'].value_counts())
# Out:
# Top 10 Suburbs by Property Count:
# suburb
# North Christopher    11
# North Michael        10
# West Robert          10
# Michaelport           9
# East Michael          9
# West Michael          9
# Williamsmouth         9
# North James           9
# Port Matthew          9
# Jamesmouth            8
# Name: count, dtype: int64
#
# Properties by State:
# state
# SA     1281
# Vic    1264
# WA     1264
# Tas    1255
# ACT    1252
# Qld    1243
# NT     1222
# NSW    1219
# Name: count, dtype: int64

# %%
# Analyze the distribution of properties by year built
if 'year_built' in df.columns:
    plt.figure(figsize=(10, 5))
    sns.histplot(df['year_built'].dropna(), bins=30, kde=True)
    plt.title("Distribution of Year Built")
    plt.xlabel("Year Built")
    plt.ylabel("Frequency")
    plt.show()

# %%
# Analyze the distribution of property availability and listing types
if 'availability' in df.columns:
    print("Availability Status Distribution:")
    print(df['availability'].value_counts())

if 'listing_type' in df.columns:
    print("\nListing Type Distribution:")
    print(df['listing_type'].value_counts())
# Out:
# Availability Status Distribution:
# availability
# Under Offer    3397
# Available      3306
# Sold           3297
# Name: count, dtype: int64
#
# Listing Type Distribution:
# listing_type
# Sale    5001
# Rent    4999
# Name: count, dtype: int64

# %%
# Analyze parking options and photo count distribution
if 'parking' in df.columns:
    print("Parking Availability Distribution:")
    print(df['parking'].value_counts())

if 'photo_count' in df.columns:
    plt.figure(figsize=(10, 5))
    sns.histplot(df['photo_count'], bins=20, kde=True)
    plt.title("Photo Count Distribution")
    plt.xlabel("Photo Count")
    plt.ylabel("Frequency")
    plt.show()
# Out:
# Parking Availability Distribution:
# parking
# 1    3391
# 0    3355
# 2    3254
# Name: count, dtype: int64

# %%
# Analyze the distribution of rent prices, if applicable
if 'rent_price' in df.columns:
    plt.figure(figsize=(10, 5))
    sns.histplot(df['rent_price'], bins=30, kde=True)
    plt.title("Rent Price Distribution")
    plt.xlabel("Rent Price")
    plt.ylabel("Frequency")
    plt.show()

# %%
# Analyze the confidence level of estimated values
if 'estimated_price_confidence' in df.columns:
    plt.figure(figsize=(10, 5))
    sns.histplot(df['estimated_price_confidence'], bins=20, kde=True)
    plt.title("Estimated Price Confidence Distribution")
    plt.xlabel("Confidence Level")
    plt.ylabel("Frequency")
    plt.show()
